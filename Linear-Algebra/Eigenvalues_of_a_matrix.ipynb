# %%
def calculate_eigenvalues(matrix):
    a = matrix[0][0]
    b = matrix[0][1]
    c = matrix[1][0]
    d = matrix[1][1]

    trace = a + d
    determinant = a * d - b * c

    discriminant = trace**2 - 4 * determinant

    lambda_1 = (trace + discriminant**0.5) / 2
    lambda_2 = (trace - discriminant**0.5) / 2

    return [lambda_1, lambda_2]


# Input
matrix = []

print("Enter a 2x2 matrix:")

for i in range(2):
    row = list(map(float, input(f"Enter row {i+1} (space-separated): ").split()))
    matrix.append(row)

# Output
eigenvalues = calculate_eigenvalues(matrix)

print("Eigenvalues:", eigenvalues)
# Out:
# Enter a 2x2 matrix:
# Enter row 1 (space-separated): 2 4
# Enter row 2 (space-separated): 3 6
# Eigenvalues: [8.0, 0.0]
